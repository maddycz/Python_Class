# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.head(20)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
# ...

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.shape
# Out:
# (212331, 15)

# %%
#searching if any null numbers-no missing values
df.isnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
# 212330       False        False         False         False  False
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0              False       False                    False
# ...

# %%
df[df['Number Scoring CR'] == 'na'].count()
# Out:
# School DBN                     142680
# School Name                    142680
# School Level                   142680
# Regents Exam                   142678
# Year                           142680
# Total Tested                   142680
# Mean Score                     142680
# Number Scoring Below 65        142680
# Percent Scoring Below 65       142680
# Number Scoring 65 or Above     142680
# Percent Scoring 65 or Above    142680
# Number Scoring 80 or Above     142680
# Percent Scoring 80 or Above    142680
# Number Scoring CR              142680
# Percent Scoring CR             142680
# dtype: int64

# %%
#drops rows that do not have info on at least 13 columns
df.dropna(thresh=13)
df_drop=df.dropna(thresh=13)
df_drop
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
#drop all rows that contain 's'
df_drop=df.drop(df[df['Mean Score'] == 's', ['Number Scoring Below 65'] == 's', ['Percent Scoring Below 65'] == 's', ['Number Scoring 65 or Above'] == 's', ['Percent Scoring 65 or Above'] == 's', ['Number Scoring 80 or Above'] == 's', ['Percent Scoring 80 or Above'] == 's'].index)

df_drop
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0          True
# 1         False
# 2         False
# 3          True
# 4          True
#           ...
# 212326     True
# 212327     True
# 212328     True
# 212329     True
# 212330     True
# Name: Mean Score, Length: 212331, dtype: bool, False, False, False, False, False, False)' is an invalid key
#
# ...

# %%
#Boolean Mask to mask/drop all rows with "s"
mask1= df['Mean Score'] == 's', ['Number Scoring Below 65'] == 's', ['Percent Scoring Below 65'] == 's'

mask2= df['Number Scoring 65 or Above'] == 's', ['Percent Scoring 65 or Above'] == 's', ['Number Scoring 80 or Above'] == 's', ['Percent Scoring 80 or Above'] == 's'

#select all rows except the ones that contain 's'
df_mask= df[~'mask1' + ~'mask2']

#show results with mask
df_mask

# %%
#Boolean Mask to mask/drop all rows with "s"
mask= (df['Mean Score'] == 's'| df['Number Scoring Below 65'] == 's'| df['Percent Scoring Below 65'] == 's'| df['Number Scoring 65 or Above'] == 's'| df['Percent Scoring 65 or Above'] == 's'| df['Number Scoring 80 or Above'] == 's'| df['Percent Scoring 80 or Above'] == 's')

#select all rows except the ones that contain 's'
df_mask= df.index[mask]

#show results with mask
df_mask

# %%
['Number Scoring 65 or Above'] == 's', ['Percent Scoring 65 or Above'] == 's', mask= df['Mean Score'] == 's', ['Number Scoring Below 65'] == 's', ['Percent Scoring Below 65'] == 's', ['Number Scoring 65 or Above'] == 's', ['Percent Scoring 65 or Above'] == 's', ['Number Scoring 80 or Above'] == 's', ['Percent Scoring 80 or Above'] == 's'

# %%
#dropping 
list= ['Mean Score','Number Scoring Below 65','Percent Scoring Below 65','Number Scoring 65 or Above', 'Percent Scoring 65 or Above', 'Number Scoring 80 or Above', 'Percent Scoring 80 or Above']
         
df_drop = df[(df['list'] !='s').all (axis=1)]

# %%
#matching
df[df['Mean Score']=='s',['Number Scoring Below 65']=='s',['Percent Scoring Below 65']=='s',['Number Scoring 65 or Above']=='s', ['Percent Scoring 65 or Above']=='s',['Number Scoring 80 or Above']=='s',['Percent Scoring 80 or Above']== 's']]

# %%
df_edit=df[df['Mean Score']=='s',['Number Scoring Below 65']=='s',['Percent Scoring Below 65']=='s',['Number Scoring 65 or Above']=='s', ['Percent Scoring 65 or Above']=='s',['Number Scoring 80 or Above']=='s',['Percent Scoring 80 or Above']=='s']
df.remove('df_edit')

# %%
#matching for mean score in order to remove the blank 's'
df[df['Mean Score'] == 's']
df_MeanScore=df[df['Mean Score'] == 's']
df_MeanScore
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 15         01M188      P.S. 188 The Island School          K-8
# 17         01M188      P.S. 188 The Island School          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 3               Common Core Algebra  2016             3          s
# ...

# %%
df_new=df.drop(df_MeanScore.index)
df_new
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 5          01M140          P.S. 140 Nathan Straus          K-8
# 6          01M140          P.S. 140 Nathan Straus          K-8
# 7          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
# 212324     84X717            Icahn Charter School          K-8
# 212325     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 1        Living Environment  2015            16       77.9
# 2        Living Environment  2016             9         74
# ...

# %%
#limiting search to 2015 Common Core Algebra
df_new[df_new['Year'] == '2015']
df_2015=df_new[df_new['Year'] == '2015']
df_2015

#df_2015[df_2015['Regents Exam'] == 'Common Core Algebra']
#df_2015Algebra=df_2015[df_2015['Regents Exam'] == 'Common Core Algebra']
#df_2015Algebra.head(20)

# %%
#limiting Search to Common Core Algebra
df_new[df_new['Regents Exam']== 'Common Core Algebra']
df_Algebra=df_new[df_new['Regents Exam']== 'Common Core Algebra']
df_Algebra.head(20)
# Out:
#     School DBN                          School Name  \
# 8       01M184                 P.S. 184m Shuang Wen
# 9       01M184                 P.S. 184m Shuang Wen
# 10      01M184                 P.S. 184m Shuang Wen
# 12      01M188           P.S. 188 The Island School
# 13      01M188           P.S. 188 The Island School
# 14      01M188           P.S. 188 The Island School
# 20      01M292           Orchard Collegiate Academy
# 21      01M292           Orchard Collegiate Academy
# 22      01M292           Orchard Collegiate Academy
# 55      01M378            School for Global Leaders
# 56      01M378            School for Global Leaders
# 57      01M378            School for Global Leaders
# 62      01M448  University Neighborhood High School
# 63      01M448  University Neighborhood High School
# 64      01M448  University Neighborhood High School
# 96      01M450           East Side Community School
# 97      01M450           East Side Community School
# ...

# %%
#filtering by year 2015 only
df_Algebra[df_Algebra['Year']==2015]
df_2015=df_Algebra[df_Algebra['Year']==2015]
df_2015
# Out:
#        School DBN                                        School Name  \
# 8          01M184                               P.S. 184m Shuang Wen
# 12         01M188                         P.S. 188 The Island School
# 20         01M292                         Orchard Collegiate Academy
# 55         01M378                          School for Global Leaders
# 62         01M448                University Neighborhood High School
# ...           ...                                                ...
# 211979     84X553  New Visions Charter High School for the Humani...
# 212107     84X703                   Bronx Preparatory Charter School
# 212108     84X703                   Bronx Preparatory Charter School
# 212223     84X704                        KIPP Academy Charter School
# 212224     84X704                        KIPP Academy Charter School
#
#                            School Level         Regents Exam  Year  \
# 8                                   K-8  Common Core Algebra  2015
# ...

# %%
#limiting to K-8 schools only
df_2015[df_2015['School Level']== 'K-8']
df_K8=df_2015[df_2015['School Level']== 'K-8']
df_K8.head (20)
# Out:
#      School DBN                                        School Name  \
# 8        01M184                               P.S. 184m Shuang Wen
# 12       01M188                         P.S. 188 The Island School
# 324      02M126                         P.S. 126 Jacob August Riis
# 391      02M217                     P.S./I.S. 217 Roosevelt Island
# 410      02M276                           Battery Park City School
# 2376     03M180                               P.S. 180 Hugo Newman
# 2472     03M333             P.S. 333 Manhattan School for Children
# 2477     03M334                                The Anderson School
# 2884     04M012                                 Tag Young Scholars
# 2898     04M057                               James Weldon Johnson
# 2911     04M171                             P.S. 171 Patrick Henry
# 2917     04M206                        P.S. 206 Jose Celso Barbosa
# 3187     05M129                            P.S. 129 John H. Finley
# ...

# %%
#comparing row 8 (PS184m) to row 2884 (Tag Young Scholars)
df_K8[df_K8['School Name']=='P.S. 184m Shuang Wen' and ['School Name']=='Tag Young Scholars']
df_K8s=df_K8[df_K8['School Name']=='P.S. 184m Shuang Wen' and ['School Name']=='Tag Young Scholars']
df_K8s



#df_2015[df_2015['School Level']== 'K-8']
#df_K8=df_2015[df_2015['School Level']== 'K-8']


#df_K8.loc[(df_K8['School DBN']=='01M184') & (df_K8['School DBN']=='04M0l2')]

#=df_k8[(df_K8.'School DBN' == '01M184') & (df_K8.'School DBN' == '04M012')]

#df.loc[(df['Discount'] >= 1000) & (df['Discount'] <= 2000)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mc/yr5t0bfj44l_9j4l8kdtkj540000gp/T/ipykernel_2205/672150576.py in ?()
#       1 #comparing row 8 (PS184m) to row 2884 (Tag Young Scholars)
# ----> 2 df_K8[df_K8['School Name']=='P.S. 184m Shuang Wen' and ['School Name']=='Tag Young Scholars']
#       3 df_K8s=df_K8[df_K8['School Name']=='P.S. 184m Shuang Wen' and ['School Name']=='Tag Young Scholars']
#       4 df_K8s
#       5
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ...

# %%
#df_K88=df_K8.iloc[8] 
#df_K88

df_K82=df_K8.iloc[2884]
#print (df_K88 & df_K82)

# %%
df_Algebra[df_Algebra['Year']==2015]
df_2015=df_Algebra[df_Algebra['Year']==2015]
df_2015

df_2015[df_2015['School Level']== 'K-8']
df_K8=df_2015[df_2015['School Level']== 'K-8']


df_K8[df_K8 ['School DBN']==01M184]
df_K88=df_K8[df_K8 ['School DBN']==01M184]
df_k88
# Out:
#   Cell In[18], line 9
#     df_K8[df_K8 ['School DBN']==01M184]
#                                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
#subset of School 01m184 only
df_K8[df_K8 ['School DBN']=='01M184']
df_K8s1=df_K8[df_K8 ['School DBN']=='01M184']
df_K8s1
# Out:
#        School DBN           School Name School Level         Regents Exam  \
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54251      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102895     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102896     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 139903     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
#
#         Year  Total Tested Mean Score Number Scoring Below 65  \
# 8       2015            49       78.4                       1
# 54251   2015            36         78                       1
# 102895  2015            28         78                       0
# 102896  2015            21       78.9                       1
# 139903  2015            42       79.1                       0
#
#        Percent Scoring Below 65 Number Scoring 65 or Above  \
# 8                             2                         48
# ...

# %%
#means of all values for School DBN 01M184
df_K8s1['Total Tested'].sum()
# Out:
# 176

# %%
print(df_K8s1['Total Tested'].dtype)
# Out:
# int64

# %%
# mean of Mean Score Column
df_K8s1['Mean Score'].sum()

# %%
print(df_K8s1['Mean Score'].dtype)
# Out:
# object

# %%
df_K8s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 8 to 139903
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School DBN                   5 non-null      object
#  1   School Name                  5 non-null      object
#  2   School Level                 5 non-null      object
#  3   Regents Exam                 5 non-null      object
#  4   Year                         5 non-null      int64
#  5   Total Tested                 5 non-null      int64
#  6   Mean Score                   5 non-null      object
#  7   Number Scoring Below 65      5 non-null      object
#  8   Percent Scoring Below 65     5 non-null      object
#  9   Number Scoring 65 or Above   5 non-null      object
#  10  Percent Scoring 65 or Above  5 non-null      object
#  11  Number Scoring 80 or Above   5 non-null      object
#  12  Percent Scoring 80 or Above  5 non-null      object
# ...

# %%
df_K8s1["Mean Score"].astype(float)
# Out:
# 8         78.4
# 54251     78.0
# 102895    78.0
# 102896    78.9
# 139903    79.1
# Name: Mean Score, dtype: float64

# %%
df_K8s1.sort_values('Mean Score')
# Out:
#        School DBN           School Name School Level         Regents Exam  \
# 54251      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102895     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102896     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 139903     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
#
#         Year  Total Tested Mean Score Number Scoring Below 65  \
# 54251   2015            36         78                       1
# 102895  2015            28         78                       0
# 8       2015            49       78.4                       1
# 102896  2015            21       78.9                       1
# 139903  2015            42       79.1                       0
#
#        Percent Scoring Below 65 Number Scoring 65 or Above  \
# 54251                       2.8                         35
# ...

# %%
#df_K8s1['Mean Score'] = pd.to_numeric(df_K8s1['Mean Score'])
df_K8s1=df_K8s1['Mean Score'].astype(int)


#df = df[df['my_col'].notnull()].copy()
#df['my_col'] = df['my_col'].astype(int).astype(str)

# %%
df_K8s1['Mean Score'].sum()

# %%
df_K8s1['Mean Score'].sum()

# %%
dfNewRow = {'School DBN': '01M184', 'School Leve': 'K-8', 'Regents Exam': 'Common Core Algebra', 'Year':'2015', 'Total Tested':'176', 'Mean Score':'78.5'}
df_K8s1 = pd.DataFrame(dfNewRow)

# %%
df_K8s1.plot(kind="bar", y= 'Total Tested', x= 'Mean Score')

# %%
x= df_K8s1['Mean Score'].sum()
df_K8s1.plot.bar(x, 'Total Tested')

# %%
#subset of School 04M012 only
df_K8[df_K8 ['School DBN']=='04M012'] 
df_K8s2=df_K8[df_K8 ['School DBN']=='04M012']
df_K8s2
# Out:
#        School DBN         School Name School Level         Regents Exam  Year  \
# 2884       04M012  Tag Young Scholars          K-8  Common Core Algebra  2015
# 108386     04M012  Tag Young Scholars          K-8  Common Core Algebra  2015
# 108387     04M012  Tag Young Scholars          K-8  Common Core Algebra  2015
# 151508     04M012  Tag Young Scholars          K-8  Common Core Algebra  2015
# 151510     04M012  Tag Young Scholars          K-8  Common Core Algebra  2015
#
#         Total Tested Mean Score Number Scoring Below 65  \
# 2884              45       71.9                      11
# 108386            24       71.1                       8
# 108387            21       72.8                       3
# 151508            14       78.1                       1
# 151510            17       68.8                       6
#
#        Percent Scoring Below 65 Number Scoring 65 or Above  \
# 2884                       24.4                         34
# ...

# %%
df_K8s2.plot(kind="hist", Title= 2015 Common Core Algebra Tag Young Scholars,  )

# %%
df_K8s2, df_K8s1
df_K8ss=df_K8s2, df_K8s1
df_K8ss

# %%
#concating 2 subsets together
df_K8ss = pd.concat([df_K8s1, df_K8s2], axis=0)
df_K8ss

# %%
df_K8ss.plot(kind='hist',y= 'Total Tested', x= 'Mean Score', 'P.S. 184m Shuang Wen'=='Yellow','Tag Young Scholars'=='Green' )

# %%
df_K8ss.plot(kind='bar', y='Total Tested', x='Mean Score')

# %%
#df_K8ss

color = 7*['yellow']
color[-2] = 'blue'
color [-1] = 'blue'
#color [0] = 'blue'
#color [-5] = 'blue'
#color [-6] = 'blue'

df_K8ss.plot(kind='bar',x='Mean Score',y='Total Tested', color=color)
plt.show()

# %%
# Make a data definition
a1 = [2.2, 2.7, 3.2, 3.7, 4.2, 4.7]
b1 = [2, 5, 8, 11, 14, 17]
 
a2 = [4, 10, 14, 20, 24, 32]
b2 = [2.3, 5.5, 11, 18, 8.9, 10.2]
 
r1 = np.arange(6)
width1 = 0.5
 
# Create the first subplot
plot.subplot(1, 2, 2)
plot.bar(r1, a1, width=width1)
plot.bar(r1 + width1, b1, width=width1)
 
# Create the second subplot
plot.subplot(1, 2, 1)
plot.bar(r1, a2, width=width1)
plot.bar(r1 + width1, b2, width=width1)
 
# Display the plot
plot.show()

# %%
df_K8s2.plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'yellow')
plt.title("Tag Young Scholars 2015 Common Core Algebra Regents Results")
plt.xlabel("Mean Score")
plt.ylabel("Total Tested")
df_K8s1.sort_values('Mean Score').plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'orange')
plt.title("P.S. 184m Shuang Wen 2015 Common Core Algebra Regents Results")
plt.xlabel("Mean Score")
plt.ylabel("Total Tested")
plt.show()

# %%
df_K8s2.plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'yellow')
df_K8s2.plot.suptitle('P.S. 184m Shuang Wen 2015 Common Core Algebra Comparison')
df_K8s1.plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'orange')
df_K8s1.plot.suptitle('Tag Young Scholars 2015 Common Core Algebra Comparison')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 2
#       1 df_K8s2.plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'yellow')
# ----> 2 df_K8s2.plot.suptitle('P.S. 184m Shuang Wen 2015 Common Core Algebra Comparison')
#       3 df_K8s1.plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'orange')
#       4 df_K8s1.plot.suptitle('Tag Young Scholars 2015 Common Core Algebra Comparison')
#
# AttributeError: 'PlotAccessor' object has no attribute 'suptitle'

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('P.S. 184m Shuang Wen VS. Tag Young Scholars 2015 Common Core Algebra Comparison')
ax1.plot([df_K8s1])
ax2.plot([df_K8s2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 fig, (ax1, ax2) = plt.subplots(1, 2)
#       2 fig.suptitle('P.S. 184m Shuang Wen VS. Tag Young Scholars 2015 Common Core Algebra Comparison')
# ----> 3 ax1.plot([df_K8s1])
#       4 ax2.plot([df_K8s2])
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# ...

# %%
plotdata = df_K8ss

    #"2018":[57,67,77,83],

    #"2019":[68,73,80,79],

    #"2020":[73,78,80,85]},

#index=["68.8", "71.1", "71.9", "72.8","78", "78.1", "78.4", "78.9", "79.1"]

plotdata.plot(kind="bar",figsize=(15, 8), y= 'Total Tested', x= 'Mean Score')

plt.title('Mean Scores in 2015 for Both P.S. 184m and Tag Young Scholars')

plt.xlabel('Mean Score')

plt.ylabel('Total Tested')

# %%
df_K8s1.groupby(['Mean Score']).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_K8s1.groupby(['Mean Score']).sort_values(ascending=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
#limiting to 02M (02 district/manhattan) schools only
df_K8M=df_K8[df_K8['School DBN'].str.contains('02M')]
df_K8M
# Out:
#        School DBN                     School Name School Level  \
# 324        02M126      P.S. 126 Jacob August Riis          K-8
# 391        02M217  P.S./I.S. 217 Roosevelt Island          K-8
# 410        02M276        Battery Park City School          K-8
# 20041      02M126      P.S. 126 Jacob August Riis          K-8
# 20042      02M126      P.S. 126 Jacob August Riis          K-8
# 55035      02M126      P.S. 126 Jacob August Riis          K-8
# 103495     02M126      P.S. 126 Jacob August Riis          K-8
# 103496     02M126      P.S. 126 Jacob August Riis          K-8
# 103666     02M276        Battery Park City School          K-8
# 103667     02M276        Battery Park City School          K-8
# 141071     02M126      P.S. 126 Jacob August Riis          K-8
# 141073     02M126      P.S. 126 Jacob August Riis          K-8
# 141075     02M126      P.S. 126 Jacob August Riis          K-8
# 141183     02M276        Battery Park City School          K-8
#
# ...

# %%
df_K8s1.sort_values('Mean Score').plot(kind="bar", y= 'Total Tested', x= 'Mean Score', color = 'orange')
plt.title("P.S. 184m Shuang Wen 2015 Common Core Algebra Regents Results")
plt.xlabel("Mean Score")
plt.ylabel("Total Tested")
df_K8M.sort_values('Mean Score').plot(kind="bar",x= 'Mean Score',y= 'Total Tested', color = 'blue')
plt.title("All K-8 Schools District 02 in Manhattan 2015 Common Core Algebra Regents Results")
plt.xlabel("Mean Score")
plt.ylabel("Total Tested")
plt.show()
