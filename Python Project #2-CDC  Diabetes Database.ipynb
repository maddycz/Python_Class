# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#removing the '?'
missing_values=['?']
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv',na_values=missing_values)
# Out:
# /var/folders/mc/yr5t0bfj44l_9j4l8kdtkj540000gp/T/ipykernel_1082/880278714.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv',na_values=missing_values)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)    NaN
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)    NaN
# 101763     443854148     41088789        Caucasian    Male  [70-80)    NaN
# 101764     443857166     31693671        Caucasian  Female  [80-90)    NaN
# 101765     443867222    175429310        Caucasian    Male  [70-80)    NaN
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.shape
# Out:
# (101766, 50)

# %%
#trying to display max columns
pd.option_context('display.max_rows', None, 'display.max_columns', None) 
display(df)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1             149190     55629189        Caucasian  Female  [10-20)    NaN
# 2              64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3             500364     82442376        Caucasian    Male  [30-40)    NaN
# 4              16680     42519267        Caucasian    Male  [40-50)    NaN
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)    NaN
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)    NaN
# 101763     443854148     41088789        Caucasian    Male  [70-80)    NaN
# 101764     443857166     31693671        Caucasian  Female  [80-90)    NaN
# 101765     443867222    175429310        Caucasian    Male  [70-80)    NaN
#
# ...

# %%
#displaying all the rows to view data
pd.pandas.set_option('display.max_columns', None) 
display(df)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1             149190     55629189        Caucasian  Female  [10-20)    NaN
# 2              64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3             500364     82442376        Caucasian    Male  [30-40)    NaN
# 4              16680     42519267        Caucasian    Male  [40-50)    NaN
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)    NaN
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)    NaN
# 101763     443854148     41088789        Caucasian    Male  [70-80)    NaN
# 101764     443857166     31693671        Caucasian  Female  [80-90)    NaN
# 101765     443867222    175429310        Caucasian    Male  [70-80)    NaN
#
# ...

# %%
#displaying large protion of rows and columns
pd.options.display.max_rows = 500
df.head(500)
# Out:
#      encounter_id  patient_nbr             race  gender       age weight  \
# 0         2278392      8222157        Caucasian  Female    [0-10)    NaN
# 1          149190     55629189        Caucasian  Female   [10-20)    NaN
# 2           64410     86047875  AfricanAmerican  Female   [20-30)    NaN
# 3          500364     82442376        Caucasian    Male   [30-40)    NaN
# 4           16680     42519267        Caucasian    Male   [40-50)    NaN
# 5           35754     82637451        Caucasian    Male   [50-60)    NaN
# 6           55842     84259809        Caucasian    Male   [60-70)    NaN
# 7           63768    114882984        Caucasian    Male   [70-80)    NaN
# 8           12522     48330783        Caucasian  Female   [80-90)    NaN
# 9           15738     63555939        Caucasian  Female  [90-100)    NaN
# 10          28236     89869032  AfricanAmerican  Female   [40-50)    NaN
# 11          36900     77391171  AfricanAmerican    Male   [60-70)    NaN
# ...

# %%
#replacing 'NaN' in race column to 'Other'
df['race'].fillna('Other', inplace=True)
df.head(30)
# Out:
#     encounter_id  patient_nbr             race  gender       age weight  \
# 0        2278392      8222157        Caucasian  Female    [0-10)    NaN
# 1         149190     55629189        Caucasian  Female   [10-20)    NaN
# 2          64410     86047875  AfricanAmerican  Female   [20-30)    NaN
# 3         500364     82442376        Caucasian    Male   [30-40)    NaN
# 4          16680     42519267        Caucasian    Male   [40-50)    NaN
# 5          35754     82637451        Caucasian    Male   [50-60)    NaN
# 6          55842     84259809        Caucasian    Male   [60-70)    NaN
# 7          63768    114882984        Caucasian    Male   [70-80)    NaN
# 8          12522     48330783        Caucasian  Female   [80-90)    NaN
# 9          15738     63555939        Caucasian  Female  [90-100)    NaN
# 10         28236     89869032  AfricanAmerican  Female   [40-50)    NaN
# 11         36900     77391171  AfricanAmerican    Male   [60-70)    NaN
# ...

# %%
#limiting Search to Age 50-60
df[df['age']== '[50-60)']
df_Age=df[df['age']== '[50-60)']
df_Age.head(30)
# Out:
#      encounter_id  patient_nbr             race  gender      age weight  \
# 5           35754     82637451        Caucasian    Male  [50-60)    NaN
# 16          77076     92519352  AfricanAmerican    Male  [50-60)    NaN
# 17          84222    108662661        Caucasian  Female  [50-60)    NaN
# 20         150006     22864131            Other  Female  [50-60)    NaN
# 25         221634     21861756            Other  Female  [50-60)    NaN
# 27         248916    115196778        Caucasian  Female  [50-60)    NaN
# 39         377268    104672268        Caucasian    Male  [50-60)    NaN
# 43         449142     66274866        Caucasian    Male  [50-60)    NaN
# 48         537834     90097839        Caucasian    Male  [50-60)    NaN
# 50         550098     21820806  AfricanAmerican    Male  [50-60)    NaN
# 53         591996     58497651  AfricanAmerican  Female  [50-60)    NaN
# 56         630342     93232917  AfricanAmerican  Female  [50-60)    NaN
# ...

# %%
df_Age.shape
# Out:
# (17256, 50)

# %%
#grouping by gender and race to get demographic counts
df_Age.groupby (['race'])['gender'].value_counts()
# Out:
# race             gender
# AfricanAmerican  Female    2457
#                  Male      1768
# Asian            Male        78
#                  Female      45
# Caucasian        Male      6276
#                  Female    5559
# Hispanic         Female     218
#                  Male       185
# Other            Male       377
#                  Female     293
# Name: count, dtype: int64

# %%
df_Age2=df_Age[['race', 'gender', 'age']]
df_Age2
# Out:
#                    race  gender      age
# 5             Caucasian    Male  [50-60)
# 16      AfricanAmerican    Male  [50-60)
# 17            Caucasian  Female  [50-60)
# 20                Other  Female  [50-60)
# 25                Other  Female  [50-60)
# ...                 ...     ...      ...
# 101715            Other    Male  [50-60)
# 101717        Caucasian    Male  [50-60)
# 101720        Caucasian    Male  [50-60)
# 101731        Caucasian    Male  [50-60)
# 101745        Caucasian    Male  [50-60)
#
# [17256 rows x 3 columns]

# %%
df_Age2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17256 entries, 5 to 101745
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   race    17256 non-null  object
#  1   gender  17256 non-null  object
#  2   age     17256 non-null  object
# dtypes: object(3)
# memory usage: 539.2+ KB

# %%
#subsetting to African Americans Only
df_AA=df_Age2[df_Age2['race'] == 'AfricanAmerican']
df_AA
# Out:
#                    race  gender      age
# 16      AfricanAmerican    Male  [50-60)
# 50      AfricanAmerican    Male  [50-60)
# 53      AfricanAmerican  Female  [50-60)
# 56      AfricanAmerican  Female  [50-60)
# 64      AfricanAmerican  Female  [50-60)
# ...                 ...     ...      ...
# 101621  AfricanAmerican  Female  [50-60)
# 101662  AfricanAmerican    Male  [50-60)
# 101674  AfricanAmerican  Female  [50-60)
# 101687  AfricanAmerican  Female  [50-60)
# 101692  AfricanAmerican  Female  [50-60)
#
# [4225 rows x 3 columns]

# %%
#distinguishing count of African American Females and Males Ages 50-60 with Diabetes
df_AA.groupby (['gender']).count()
# Out:
#         race   age
# gender
# Female  2457  2457
# Male    1768  1768

# %%
#getting percentage of Afican Amercian Males vs Female within 50-60 age range that have Diabetes
df_AA['gender'].value_counts(normalize=True)*100
# Out:
# gender
# Female    58.153846
# Male      41.846154
# Name: proportion, dtype: float64

# %%
#Displaying pie chart of proportion of African American Female/Males that have Diabetes within the 50-60 Age Range
df_AA['gender'].value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%')
plt.title('Percentage of African American Female/Male 50-60 Years Old with Diabetes')
# Out:
# Text(0.5, 1.0, 'Percentage of African American Female/Male 50-60 Years Old with Diabetes')

# %%
#subsetting to Asians Only
df_As=df_Age2[df_Age2['race'] == 'Asian']
df_As
# Out:
#          race  gender      age
# 384     Asian  Female  [50-60)
# 649     Asian    Male  [50-60)
# 939     Asian    Male  [50-60)
# 1073    Asian  Female  [50-60)
# 1225    Asian  Female  [50-60)
# 1670    Asian    Male  [50-60)
# 3187    Asian    Male  [50-60)
# 3237    Asian  Female  [50-60)
# 3853    Asian  Female  [50-60)
# 5822    Asian    Male  [50-60)
# 6378    Asian  Female  [50-60)
# 6872    Asian  Female  [50-60)
# 8544    Asian    Male  [50-60)
# 9072    Asian    Male  [50-60)
# 9778    Asian  Female  [50-60)
# 10242   Asian  Female  [50-60)
# 10311   Asian    Male  [50-60)
# 14922   Asian    Male  [50-60)
# 14972   Asian    Male  [50-60)
# 15162   Asian    Male  [50-60)
# 15233   Asian    Male  [50-60)
# 18563   Asian    Male  [50-60)
# 18989   Asian    Male  [50-60)
# 19488   Asian    Male  [50-60)
# 19801   Asian  Female  [50-60)
# 20782   Asian  Female  [50-60)
# 21426   Asian    Male  [50-60)
# 22223   Asian    Male  [50-60)
# 22546   Asian    Male  [50-60)
# ...

# %%
#distinguishing count of Asain Females and Males Ages 50-60 with Diabetes
df_As.groupby (['gender']).count()
# Out:
#         race  age
# gender
# Female    45   45
# Male      78   78

# %%
#getting percentage of Asain Males vs Female within 50-60 age range that have Diabetes
df_As['gender'].value_counts(normalize=True)*100
# Out:
# gender
# Male      63.414634
# Female    36.585366
# Name: proportion, dtype: float64

# %%
#Displaying pie chart of proportion of African American Female/Males that have Diabetes within the 50-60 Age Range
df_As['gender'].value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%')
plt.title('Percentage of Asian Female/Male 50-60 Years Old with Diabetes')
# Out:
# Text(0.5, 1.0, 'Percentage of Asian Female/Male 50-60 Years Old with Diabetes')

# %%
#subsetting to Caucasians Only
df_CC=df_Age2[df_Age2['race'] == 'Caucasian']
df_CC
# Out:
#              race  gender      age
# 5       Caucasian    Male  [50-60)
# 17      Caucasian  Female  [50-60)
# 27      Caucasian  Female  [50-60)
# 39      Caucasian    Male  [50-60)
# 43      Caucasian    Male  [50-60)
# ...           ...     ...      ...
# 101708  Caucasian  Female  [50-60)
# 101717  Caucasian    Male  [50-60)
# 101720  Caucasian    Male  [50-60)
# 101731  Caucasian    Male  [50-60)
# 101745  Caucasian    Male  [50-60)
#
# [11835 rows x 3 columns]

# %%
#distinguishing count of Caucasian Females and Males Ages 50-60 with Diabetes
df_CC.groupby (['gender']).count()
# Out:
#         race   age
# gender
# Female  5559  5559
# Male    6276  6276

# %%
#getting percentage of Caucasian Males vs Female within 50-60 age range that have Diabetes
df_CC['gender'].value_counts(normalize=True)*100
# Out:
# gender
# Male      53.029151
# Female    46.970849
# Name: proportion, dtype: float64

# %%
#Displaying pie chart of proportion of Caucasian Female/Males that have Diabetes within the 50-60 Age Range
df_CC['gender'].value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%')
plt.title('Percentage of Caucasian Female/Male 50-60 Years Old with Diabetes')
# Out:
# Text(0.5, 1.0, 'Percentage of Caucasian Female/Male 50-60 Years Old with Diabetes')

# %%
#subsetting to Hispanics Only
df_Hs=df_Age2[df_Age2['race'] == 'Hispanic']
df_Hs
# Out:
#             race  gender      age
# 961     Hispanic  Female  [50-60)
# 1097    Hispanic  Female  [50-60)
# 1125    Hispanic  Female  [50-60)
# 1228    Hispanic    Male  [50-60)
# 1253    Hispanic    Male  [50-60)
# 1581    Hispanic    Male  [50-60)
# 1647    Hispanic  Female  [50-60)
# 1718    Hispanic    Male  [50-60)
# 2483    Hispanic  Female  [50-60)
# 2724    Hispanic  Female  [50-60)
# 3174    Hispanic  Female  [50-60)
# 3295    Hispanic    Male  [50-60)
# 3399    Hispanic    Male  [50-60)
# 4020    Hispanic  Female  [50-60)
# 4374    Hispanic  Female  [50-60)
# 5053    Hispanic  Female  [50-60)
# 5055    Hispanic  Female  [50-60)
# 5076    Hispanic  Female  [50-60)
# 5405    Hispanic  Female  [50-60)
# 5972    Hispanic  Female  [50-60)
# 5977    Hispanic  Female  [50-60)
# 6163    Hispanic    Male  [50-60)
# 6201    Hispanic  Female  [50-60)
# 6481    Hispanic  Female  [50-60)
# 6913    Hispanic    Male  [50-60)
# 6990    Hispanic  Female  [50-60)
# ...

# %%
#distinguishing count of Hispanic Females and Males Ages 50-60 with Diabetes
df_Hs.groupby (['gender']).count()
# Out:
#         race  age
# gender
# Female   218  218
# Male     185  185

# %%
#getting percentage of Hispanic Males vs Female within 50-60 age range that have Diabetes
df_Hs['gender'].value_counts(normalize=True)*100
# Out:
# gender
# Female    54.094293
# Male      45.905707
# Name: proportion, dtype: float64

# %%
#Displaying pie chart of proportion of Hispanic Female/Males that have Diabetes within the 50-60 Age Range
df_Hs['gender'].value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%')
plt.title('Percentage of Hispanic Female/Male 50-60 Years Old with Diabetes')
# Out:
# Text(0.5, 1.0, 'Percentage of Hispanic Female/Male 50-60 Years Old with Diabetes')

# %%
#subsetting to Other Only
df_Ot=df_Age2[df_Age2['race'] == 'Other']
df_Ot
# Out:
#          race  gender      age
# 20      Other  Female  [50-60)
# 25      Other  Female  [50-60)
# 98      Other  Female  [50-60)
# 106     Other  Female  [50-60)
# 124     Other    Male  [50-60)
# ...       ...     ...      ...
# 101362  Other    Male  [50-60)
# 101398  Other    Male  [50-60)
# 101419  Other  Female  [50-60)
# 101499  Other    Male  [50-60)
# 101715  Other    Male  [50-60)
#
# [670 rows x 3 columns]

# %%
#distinguishing count of Other Females and Males Ages 50-60 with Diabetes
df_Ot.groupby (['gender']).count()
# Out:
#         race  age
# gender
# Female   293  293
# Male     377  377

# %%
#getting percentage of Other Males vs Female within 50-60 age range that have Diabetes
df_Ot['gender'].value_counts(normalize=True)*100
# Out:
# gender
# Male      56.268657
# Female    43.731343
# Name: proportion, dtype: float64

# %%
#Displaying pie chart of proportion of Other Female/Males that have Diabetes within the 50-60 Age Range
df_Ot['gender'].value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%')
plt.title('Percentage of Other Female/Male 50-60 Years Old with Diabetes')
# Out:
# Text(0.5, 1.0, 'Percentage of Other Female/Male 50-60 Years Old with Diabetes')

# %%
#distinguishing count of All Males vs Female within 50-60 age range that have Diabetes grouped by race and gender
df_Age2.groupby (['race'])['gender'].value_counts()
# Out:
# race             gender
# AfricanAmerican  Female    2457
#                  Male      1768
# Asian            Male        78
#                  Female      45
# Caucasian        Male      6276
#                  Female    5559
# Hispanic         Female     218
#                  Male       185
# Other            Male       377
#                  Female     293
# Name: count, dtype: int64

# %%
#getting percentage of All Males vs Female within 50-60 age range that have Diabetes grouped by race and gender
df_Age2.groupby (['race'])['gender'].value_counts(normalize=True)*100
# Out:
# race             gender
# AfricanAmerican  Female    58.153846
#                  Male      41.846154
# Asian            Male      63.414634
#                  Female    36.585366
# Caucasian        Male      53.029151
#                  Female    46.970849
# Hispanic         Female    54.094293
#                  Male      45.905707
# Other            Male      56.268657
#                  Female    43.731343
# Name: proportion, dtype: float64

# %%
#Displaying proportion grouped by race and Gender that have Diabetes within the 50-60 Age Range
df_Age2.groupby (['race'])['gender'].value_counts(normalize=True).plot(kind='bar', color=['blue', 'blue', 'orange', 'orange', 'green', 'green', 'yellow', 'yellow','purple','purple'])
plt.title('Percentage of Race by Gender 50-60 Years Old with Diabetes')
# Out:
# Text(0.5, 1.0, 'Percentage of Race by Gender 50-60 Years Old with Diabetes')

# %%
#Analysis
#females in the demographic of African Americans and Hispanic within the ages of 50-60 years old have a larger 
#proportion of having diabetes than their male counterparts. Caucasian males have a slightly larger proportion than 
#their female counterparts. Most significantly however, Asain females and males have the largest difference between
#their genders, with males making up 26% more than the females in having diabetes.
